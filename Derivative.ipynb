# %%
import numpy as np
import scipy
import sklearn
import matplotlib.pyplot as plt
import matplotlib as mpl
import sympy
import pandas
import torch
# import jtplot module in notebook
from jupyterthemes import jtplot

# choose which theme to inherit plotting style from
# onedork | grade3 | oceans16 | chesterish | monokai | solarizedl | solarizedd
jtplot.style(theme='onedork')

# %%
# lambad, enumerate 표현 익혀두기.

fig, ax = plt.subplots(1,3, sharex=True)
fig.set_size_inches(24,6)

f = lambda x : x ** 4

xs = [-1, 0, 1]
#ls = ['-', '-', '-']
df = lambda h : (f(x+h)-f(x)) / h

h = np.linspace(-0.1, 0.1, 100)

for idx, x in enumerate(xs):
    ax[idx].plot(h,df(h), lw=1, color='b')
    ax[idx].plot(0,df(0.00001), 'o', markersize=13, markerfacecolor='k',
                markeredgewidth=1.5, markeredgecolor='r')
    ax[idx].set_title(fr'$x = {x}$', fontsize=20)
    ax[idx].set_xlabel(r'$h$', fontsize=25)
    
    if idx == 0:
        ax[idx].set_ylabel(r'$f(h)$', fontsize=25)
    
    ax[idx].xaxis.set_tick_params(labelsize=18)
    ax[idx].yaxis.set_tick_params(labelsize=18)
    ax[idx].grid(False)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-9892d042a19d> in <module>
#      42     # derivative
#      43     img2_cp    = ax[1,i].plot(x0, fdot(x0), 'o', markersize=10, color='k', zorder=3)
# ---> 44     ax[1,i].add_artist(con)
#      45     img2_deriv = ax[1,i].text(x0 + 0.1 ,fdot(x0)+0.2, "Value {:.2f}".format(fdot(x0)), fontsize=20)
#      46     ax[1,i].xaxis.set_tick_params(labelsize=18)
#
# NameError: name 'con' is not defined
